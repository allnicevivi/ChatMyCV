# %%
import sys
sys.path.append("./")
sys.path.append("../")

# %%
import pprint as pp

# %%
md_file = "/Users/viviliu/Documents/10_Vivi/ChatMyCV/backend/data/resume.md"

with open(md_file, 'r', encoding='utf-8') as file:
    content = file.read()

print(content)
# print(content[:200])  # print a preview of the first 200 characters
# Out:
# ## Vivi Liu（劉米婷 Mi-Ting Liu）
#
# **Phone:** (+886) 919139582
# **Email:** allnicevivi@gmail.com
# **LinkedIn:** https://www.linkedin.com/in/vivi-liu-47a151177/
#
# ---
#
# ## Summary
#
# Results-driven AI engineer with over 3 years of experience in developing software system using various technologies. Passionate about creating efficient and scalable solutions. Strong problem-solving skills and ability to adapt quickly to new challenges.
#
# ---
#
# ## Professional Experience
#
# ### AI Engineer, NUWA Robotics
# *May 2024 - Present*
#
# - Built a RAG system from scratch, optimizing retrieval with sparse embeddings, weighted search, and metadata enrichment; improved recall rate by 30% and reduced latency by 50% (16s → 8s).
# - Developed an LLM evaluation module to log runtime, prompt variations, and test outcomes, enabling systematic experimentation and eliminating redundant tests through data-driven iteration.
# - Enhanced development efficiency by 30% using vibe coding methodology, reducing feature build/debug time from 1 day to 2–3 hours.
# - Designed and deployed custom AI agents for NER, intent classification, and multi-turn/multilingual dialogue, expanding product use cases and global market readiness.
# - Optimized system performance by implementing RabbitMQ and multithreading/async processing, enhancing scalability and reducing latency by 50%.
# - Collaborated with sales and product teams to align AI solutions with business needs, securing 10+ clients across T aiwan and Japan, with expansion into the U.S. market.
#
# ### AI Software Engineer, MetaEdge
# *February 2023 - April 2024*
#
# - Led development of in-house LLM product with RAG pipeline from scratch, achieving +10% precision
# - Implemented Semantic T extual Similarity and ModelOps workflows, leveraging fine-tuning and ensemble methods to increase precision by 20%.
# - Owned ML product lifecycle, driving end-to-end development, deployment, and optimization as product owner.
# - Refactored and optimized legacy AI systems, improving efficiency by 30%, reducing memory usage by 90%.
# - Designed database structures and performed system analysis for a new AI product, ensuring scalability and reliability.
# - Collaborated cross-functionally with data engineers, frontend engineers and PMs to scale solutions to 3+ enterprise clients
#
# ### Data Analyst, Gosky AI
# *February 2022 - December 2022*
#
# - Built ETL pipelines in BigQuery and automated dashboards for 40+ team members to enhance business-driven development.
# - Applied automatic web scraping and scheduling tools to reduce manual effort by 30%.
# - Analyzed user journeys and partnered with product managers to track behavior, driving 70%+ first-week retention.
# - Delivered 10+ actionable insights to cross-functional teams, resulting in 50% growth in new user acquisition and 70% increase in engagement.
# - Conducted RFM segmentation, increasing CRM engagement by 90% engaged conversion rate and reducing block rate
#
# ---
#
# ## Education
#
# ### B.S. in Statistics
# *National Cheng Kung University 2018 - 2022*
# - GPA: 3.94
# - Relevant Coursework: Data Structures, Algorithms, Software Engineering, Database Management.
#
# ---
#
# ## Leadership Experience
#
# ### Academic Director, NCKU Data Analytics Club
# *September 2021 - June 2022*
#
# - Organized monthly workshops and training sessions to enhance team skills.
# - Collaborate with Kdan Model for "EDM Spam Classifier" by builting CountVectorizer + Logistic/SVM classifiers, visualized domain-level spam patterns and predicted titles with high spam rates.
# [EDM Spam Classifier, Kdan Mobile](https://www.kdanmobile.com/zh-tw)
#
# ### President, Statistics Student Association, NCKU
# *October 2018 - June 2021*
#
# - Conducted numerous workshops on topics such as career development, software skills including Excel VBA, and presentation techniques, reaching a total of 600 attendees.
# - Coordinated guest speakers, arranged venues, and managed event logistics.
# - Served as a liaison between students and the academic department, facilitating effective communication and advocating for student rights and interests.
#
# ### Performance Coordinator, NCKU Dance Club
# *October 2019 - June 2021*
#
# - Managed yearly performance events, including schedule planning and coordination.
# - Led and collaborated with teams such as marketing and finance to ensure event success.
# ---
#
# ## Skills
#
# - Statistics: Statistical Analysis, Probability Theory, Regression Analysis
# - Machine Learning: Supervised Learning, Unsupervised Learning, Model Evaluation
# - Natural Language Processing (NLP): Sentiment Analysis, Text Classification, Tokenization, Named Entity Recognition
# - Programming Languages: Python, SQL
# - Tools: Git, Docker,
# - Databases: PostgreSQL, MySQL, Milvus, Faiss, ...
# - Soft Skills: Team Leadership, Communication, Problem Solving
#
# ---
#
# ## Certifications
#
# - AWS Certified Solutions Architect
# - Certified ScrumMaster (CSM)
#
# ---
#
# ## Additional Information
#
# - Volunteer at local coding bootcamps.
# - Avid blogger on technology and coding practices.
#
# ---

# %%
import imp
from typing import Any, List, Tuple, Optional, Dict
import re
from pathlib import Path
from fsspec import AbstractFileSystem
from fsspec.implementations.local import LocalFileSystem

from component.base import Node

class MarkdownReader():
    """Markdown parser.

    Extract text from markdown files.
    Returns dictionary with keys as headers and values as the text between headers.
    """

    def __init__(
        self,
        *args: Any,
        remove_hyperlinks: bool = True,
        remove_images: bool = True,
        **kwargs: Any,
    ) -> None:
        """Init params."""
        super().__init__(*args, **kwargs)
        self._remove_hyperlinks = remove_hyperlinks
        self._remove_images = remove_images

    def markdown_to_tups(self, markdown_text: str) -> List[Tuple[Optional[str], str]]:
        """Convert a markdown file to a dictionary.

        The keys are the headers and the values are the text under each header.

        """
        markdown_tups: List[Tuple[Optional[str], str]] = []
        lines = markdown_text.split("\n")

        current_header = None
        current_lines = []
        in_code_block = False

        current_layer = 0
        for line in lines:
            if line.startswith("```"):
                # This is the end of a code block if we are already in it, and vice versa.
                in_code_block = not in_code_block

            header_match = re.match(r"^#+\s", line)
            if not header_match:
                header_match = re.match(r"^#+", line)
            if not in_code_block and header_match:
                # Upon first header, skip if current text chunk is empty
                if current_header is not None or len(current_lines) > 0:
                    # print(f'current_layer: {current_layer}, current_header: {current_header}')
                    markdown_tups.append((current_layer, current_header, "\n".join(current_lines)))

                current_header = line
                current_layer = len(header_match.group().strip())
                current_lines.clear()
            else:
                current_lines.append(line)
            
        # Append final text chunk
        markdown_tups.append((current_layer, current_header, "\n".join(current_lines)))

        # Postprocess the tuples before returning
        return [
            (
                layer,
                key if key is None else re.sub(r"#", "", key).strip(),
                re.sub(r"<.*?>", "", value),
            )
            for layer, key, value in markdown_tups
        ]

    def remove_images(self, content: str) -> str:
        """Remove images in markdown content."""
        pattern = r"!{1}\[\[(.*)\]\]"
        return re.sub(pattern, "", content)

    def remove_hyperlinks(self, content: str) -> str:
        """Remove hyperlinks in markdown content."""
        pattern = r"\[(.*?)\]\((.*?)\)"
        return re.sub(pattern, r"\1", content)

    def parse_tups(
        self,
        filepath: Path,
        content: str = "",
        errors: str = "ignore",
        fs: Optional[AbstractFileSystem] = None,
    ) -> List[Tuple[Optional[str], str]]:
        """Parse file into tuples."""
        if content:
            return self.markdown_to_tups(content)
        
        fs = fs or LocalFileSystem()
        with fs.open(filepath, encoding="utf-8") as f:
            content = f.read().decode(encoding="utf-8")
        if self._remove_hyperlinks:
            content = self.remove_hyperlinks(content)
        if self._remove_images:
            content = self.remove_images(content)
        return self.markdown_to_tups(content)

    def load_data(
        self,
        file: Path,
        content: str="",
        extra_info: Optional[Dict] = None,
        fs: Optional[AbstractFileSystem] = None,
    ) -> List[Node]:
        """Parse file into string."""
        tups = self.parse_tups(file, content, fs=fs)
        results = []
        if not extra_info: extra_info = {}
        extra_info["filename"] = file.name
        # TODO: don't include headers right now
        for layer, header, value in tups:
            if header is None:
                # extra_info["is_gpt_converted"] = True
                results.append(Node(text=value, metadata=extra_info or {}))
            else:
                extra_info[f'Header_{layer}'] = header
                i = 1
                while extra_info.get(f'Header_{layer+i}', None):
                    extra_info.pop(f'Header_{layer+i}')
                    i += 1
                if not value:
                    continue
                    
                headers = '\n'.join([v for k, v in extra_info.items() if k.startswith("Header_")])
                results.append(
                    Node(text=f"{headers}\n{value}", metadata=extra_info or {})
                )
        return results

# %%
md_file = Path("/Users/viviliu/Documents/10_Vivi/ChatMyCV/backend/data/resume.md")


documents = MarkdownReader().load_data(
    file=md_file,
    # content=to_md_content,
    # extra_info={"train_id": self.rag_id}
)

pp.pprint(documents)
# Out:
# [Node(id_='b969b0ca-cccb-45f4-ba24-eaa48a35a955', text='Vivi Liu（劉米婷 Mi-Ting Liu）\n\n**Phone:** (+886) 919139582\n**Email:** allnicevivi@gmail.com\n**LinkedIn:** https://www.linkedin.com/in/vivi-liu-47a151177/\n\n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Vivi Liu（劉米婷 Mi-Ting Liu）'}),
#  Node(id_='3129c529-c0e0-4106-a362-c4316bbb4cac', text='Summary\n\nResults-driven AI engineer with over 3 years of experience in developing software system using various technologies. Passionate about creating efficient and scalable solutions. Strong problem-solving skills and ability to adapt quickly to new challenges.\n\n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Summary'}),
#  Node(id_='97fb6f30-94b3-49ee-9ef8-1244ba508f03', text='Professional Experience\nAI Engineer, NUWA Robotics\n*May 2024 - Present*\n\n- Built a RAG system from scratch, optimizing retrieval with sparse embeddings, weighted search, and metadata enrichment; improved recall rate by 30% and reduced latency by 50% (16s → 8s).\n- Developed an LLM evaluation module to log runtime, prompt variations, and test outcomes, enabling systematic experimentation and eliminating redundant tests through data-driven iteration.\n- Enhanced development efficiency by 30% using vibe coding methodology, reducing feature build/debug time from 1 day to 2–3 hours.\n- Designed and deployed custom AI agents for NER, intent classification, and multi-turn/multilingual dialogue, expanding product use cases and global market readiness.\n- Optimized system performance by implementing RabbitMQ and multithreading/async processing, enhancing scalability and reducing latency by 50%.\n- Collaborated with sales and product teams to align AI solutions with business needs, securing 10+ clients across T aiwan and Japan, with expansion into the U.S. market.\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Professional Experience', 'Header_3': 'AI Engineer, NUWA Robotics'}),
#  Node(id_='fd12b518-2c81-4f0f-9d13-9ef83f0c7196', text='Professional Experience\nAI Software Engineer, MetaEdge\n*February 2023 - April 2024*\n\n- Led development of in-house LLM product with RAG pipeline from scratch, achieving +10% precision\n- Implemented Semantic T extual Similarity and ModelOps workflows, leveraging fine-tuning and ensemble methods to increase precision by 20%.\n- Owned ML product lifecycle, driving end-to-end development, deployment, and optimization as product owner.\n- Refactored and optimized legacy AI systems, improving efficiency by 30%, reducing memory usage by 90%.\n- Designed database structures and performed system analysis for a new AI product, ensuring scalability and reliability.\n- Collaborated cross-functionally with data engineers, frontend engineers and PMs to scale solutions to 3+ enterprise clients\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Professional Experience', 'Header_3': 'AI Software Engineer, MetaEdge'}),
#  Node(id_='09233b84-3d7a-4de2-8cb6-165b9a586a7c', text='Professional Experience\nData Analyst, Gosky AI\n*February 2022 - December 2022*\n\n- Built ETL pipelines in BigQuery and automated dashboards for 40+ team members to enhance business-driven development.\n- Applied automatic web scraping and scheduling tools to reduce manual effort by 30%.\n- Analyzed user journeys and partnered with product managers to track behavior, driving 70%+ first-week retention.\n- Delivered 10+ actionable insights to cross-functional teams, resulting in 50% growth in new user acquisition and 70% increase in engagement.\n- Conducted RFM segmentation, increasing CRM engagement by 90% engaged conversion rate and reducing block rate\n\n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Professional Experience', 'Header_3': 'Data Analyst, Gosky AI'}),
#  Node(id_='0852c7ba-8b05-4a57-bcf4-c4d2e6689b9a', text='Education\nB.S. in Statistics\n*National Cheng Kung University 2018 - 2022*\n- GPA: 3.94\n- Relevant Coursework: Data Structures, Algorithms, Software Engineering, Database Management.\n\n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Education', 'Header_3': 'B.S. in Statistics'}),
#  Node(id_='886a36b3-b2b7-400a-889b-2836e952398b', text='Leadership Experience\nAcademic Director, NCKU Data Analytics Club\n*September 2021 - June 2022*\n\n- Organized monthly workshops and training sessions to enhance team skills.\n- Collaborate with Kdan Model for "EDM Spam Classifier" by builting CountVectorizer + Logistic/SVM classifiers, visualized domain-level spam patterns and predicted titles with high spam rates.\nEDM Spam Classifier, Kdan Mobile\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Leadership Experience', 'Header_3': 'Academic Director, NCKU Data Analytics Club'}),
#  Node(id_='29c22d10-8ecc-4f86-8f90-34d2df1cdd49', text='Leadership Experience\nPresident, Statistics Student Association, NCKU\n*October 2018 - June 2021*\n\n- Conducted numerous workshops on topics such as career development, software skills including Excel VBA, and presentation techniques, reaching a total of 600 attendees.\n- Coordinated guest speakers, arranged venues, and managed event logistics.\n- Served as a liaison between students and the academic department, facilitating effective communication and advocating for student rights and interests.\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Leadership Experience', 'Header_3': 'President, Statistics Student Association, NCKU'}),
#  Node(id_='57512076-d751-4e81-b2b0-721d09dfe685', text='Leadership Experience\nPerformance Coordinator, NCKU Dance Club\n*October 2019 - June 2021*\n\n- Managed yearly performance events, including schedule planning and coordination. \n- Led and collaborated with teams such as marketing and finance to ensure event success. \n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Leadership Experience', 'Header_3': 'Performance Coordinator, NCKU Dance Club'}),
#  Node(id_='7ea4bf81-106d-4175-bfda-01af381b2aee', text='Skills\n\n- Statistics: Statistical Analysis, Probability Theory, Regression Analysis\n- Machine Learning: Supervised Learning, Unsupervised Learning, Model Evaluation\n- Natural Language Processing (NLP): Sentiment Analysis, Text Classification, Tokenization, Named Entity Recognition\n- Programming Languages: Python, SQL\n- Tools: Git, Docker, \n- Databases: PostgreSQL, MySQL, Milvus, Faiss, ...\n- Soft Skills: Team Leadership, Communication, Problem Solving\n\n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Skills'}),
#  Node(id_='ecfd1e7c-c55d-4235-ab65-a4d1580f1433', text='Certifications\n\n- AWS Certified Solutions Architect\n- Certified ScrumMaster (CSM)\n\n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Certifications'}),
#  Node(id_='16795457-67f8-441f-944d-eb8bd6e6fbfa', text='Additional Information\n\n- Volunteer at local coding bootcamps.\n- Avid blogger on technology and coding practices.\n  \n---\n', embedding=None, sparse_embedding=None, node_type='text', metadata={'filename': 'resume.md', 'Header_2': 'Additional Information'})]

# %%
import re

response_content = """<thinking>
Step 1: The question asks if I am currently employed.
Step 2: The context shows that I am employed as an AI Engineer at NUWA Robotics from May 2024 to present ("至今").
Step 3: Based on this, I can confirm that I am currently working there.
Step 4: I will answer clearly and warmly, and offer to share more about my current role if interested.
</thinking>

<answer>
是的，我目前仍在 NUWA Robotics 擔任 AI 工程師，從今年五月開始至今。我主要負責從零打造檢索增強生成系統，並與產品及業務團隊密切合作。如果您想了解更多我的工作內容，隨時可以問我！"""

match = re.search(r'<answer>(.*)', response_content, re.DOTALL)
if match:
    final_answer = match.group(1).strip()
    if final_answer in ["None", "Empty Response"]:
        final_answer = None
else:
    final_answer = None
print(final_answer)
# Out:
# 是的，我目前仍在 NUWA Robotics 擔任 AI 工程師，從今年五月開始至今。我主要負責從零打造檢索增強生成系統，並與產品及業務團隊密切合作。如果您想了解更多我的工作內容，隨時可以問我！

# %%
from pathlib import Path

directory_path = Path("/Users/viviliu/Documents/10_Vivi/ChatMyCV/backend/data")
lang_folder = [p for p in directory_path.iterdir() if p.is_dir()]

for folder in lang_folder:
    print(folder.name)
    files = list(folder.iterdir())
    print(files)
# Out:
# en
# [PosixPath('/Users/viviliu/Documents/10_Vivi/ChatMyCV/backend/data/en/resume.md'), PosixPath('/Users/viviliu/Documents/10_Vivi/ChatMyCV/backend/data/en/resume_detail.md')]
# zhtw
# [PosixPath('/Users/viviliu/Documents/10_Vivi/ChatMyCV/backend/data/zhtw/resume_detail_zhtw.md')]

# %%
directory_path
# Out:
# PosixPath('/Users/viviliu/Documents/10_Vivi/ChatMyCV/backend/data')

# %%
files[0].parts[-1]
# Out:
# 'en'
